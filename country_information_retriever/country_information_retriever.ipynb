# %%
pip install countryinfo

# %%
from countryinfo import CountryInfo

# %%
def get_country_info(country_name):
  country = CountryInfo(country_name)
  print("Capital is:", country.capital())
  print("Currencies is/are: ", country.currencies())
  print("Languages is/are: ", country.languages())
  print("Borders are:", country.borders())
  print("Other names: ", country.alt_spellings())

get_country_info("Philippines")
# Out:
# Capital is: Manila
# Currencies is/are:  ['PHP']
# Languages is/are:  ['en']
# Borders are: []
# Other names:  ['PH', 'Republic of the Philippines', 'Repúblika ng Pilipinas']

# %%
get_country_info("Germany")
# Out:
# Capital is: Berlin
# Currencies is/are:  ['EUR']
# Languages is/are:  ['de']
# Borders are: ['AUT', 'BEL', 'CZE', 'DNK', 'FRA', 'LUX', 'NLD', 'POL', 'CHE']
# Other names:  ['DE', 'Federal Republic of Germany', 'Bundesrepublik Deutschland']

# %%
get_country_info("Russia")
# Out:
# Capital is: Moscow
# Currencies is/are:  ['RUB']
# Languages is/are:  ['ru']
# Borders are: ['AZE', 'BLR', 'CHN', 'EST', 'FIN', 'GEO', 'KAZ', 'PRK', 'LVA', 'LTU', 'MNG', 'NOR', 'POL', 'UKR']
# Other names:  ['RU', 'Rossiya', 'Russian Federation', 'Российская Федерация', 'Rossiyskaya Federatsiya']
