# %%
import prettytable
from prettytable import PrettyTable

# %%
table = PrettyTable(["Name", "Age"])
table.add_row(["John", 25])
table.add_row(["Mike", 30])
print(table)
# Out:
# +------+-----+
# | Name | Age |
# +------+-----+
# | John |  25 |
# | Mike |  30 |
# +------+-----+
